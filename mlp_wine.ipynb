# %% [markdown]
# <a href="https://colab.research.google.com/github/anusree-t-s/deep-learning/blob/master/mlp_wine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.datasets import load_wine

# %%
from sklearn.neural_network import MLPClassifier
X, y = load_wine(return_X_y=True)
print(type(X))
print(X.shape)
print(y.shape)
# Out:
# <class 'numpy.ndarray'>
# (178, 13)
# (178,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,stratify=y, random_state=42)
mlpClassifier = MLPClassifier(solver='lbfgs', alpha=1e-5,hidden_layer_sizes=(25, 25), random_state=1)

# %%
mlpClassifier.fit(X_train, y_train)
score = mlpClassifier.score(X_test, y_test)

print(score)
# Out:
# 0.9629629629629629

# %%
print(mlpClassifier.coefs_)
# Out:
# [array([[-0.06567963,  0.16469197, -0.42081825, -0.1369498 , -0.28072994,
#         -0.32567456, -0.24933509, -0.12273588, -0.07687769,  0.03084841,
#         -0.04137959,  0.13742955, -0.23487752,  0.30049725, -0.37559424,
#          0.13153657, -0.06396079,  0.04664194, -0.28579147, -0.24166504,
#          0.23900754,  0.36059913, -0.14827542,  0.15284251,  0.30383731],
#        [ 0.3447515 , -0.33588539, -0.39011478, -0.28292399,  0.30051717,
#         -0.31940361, -0.0626973 ,  0.36389368,  0.03969414,  0.15248846,
#         -0.13339258,  0.12040874,  0.2659335 , -0.38282564,  0.19879453,
#          0.38703207,  0.18221058, -0.17448541,  0.22989589, -0.30630372,
#         -0.04141002,  0.33117731, -0.16401883, -0.16865905, -0.27854193],
#        [-0.37755431,  0.14009924, -0.23544554, -0.18673518, -0.00669697,
#         -0.35524748,  0.0589027 , -0.28075165,  0.07340878,  0.15875184,
#         -0.3117021 , -0.07306276,  0.15449357, -0.0682034 , -0.35766071,
# ...
